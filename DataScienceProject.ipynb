# %% [markdown]
# ## Basic Info

# %% [markdown]
# ## Background and Motivation

# %% [markdown]
# ## Project Objectives (Hypothesis)

# %% [markdown]
# ## Data Sources

# %% [markdown]
# ## Data Models

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ## Data Analysis

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ## The Team
